# %%
import os
import pyemu

# %%
model_ws = os.path.join("monthly_model_files_1lyr_newstress")

# %%
pyemu.os_utils.run('mf6',cwd=model_ws)

# %%
pyemu.utils.PstFrom?
# Out:
# Init signature:
# pyemu.utils.PstFrom(
#     original_d,
#     new_d,
#     longnames=True,
#     remove_existing=False,
#     spatial_reference=None,
#     zero_based=True,
#     start_datetime=None,
#     tpl_subfolder=None,
#     chunk_len=50,
#     echo=True,
# )
# Docstring:
# construct high-dimensional PEST(++) interfaces with all the bells and whistles
#
# Args:
#     original_d (`str` or Path): the path to a complete set of model input and output files
#     new_d (`str` or Path): the path to where the model files and PEST interface files will be copied/built
#     longnames (`bool`): flag to use longer-than-PEST-likes parameter and observation names.  Default is True
#     remove_existing (`bool`): flag to destroy any existing files and folders in `new_d`.  Default is False
#     spatial_reference (varies): an object that faciliates geo-locating model cells based on index.  Default is None
#     zero_based (`bool`): flag if the model uses zero-based indices, Default is True
#     start_datetime (`str` or Timestamp): a string that can be case to a datatime instance the represents the starting datetime
#         of the model
#     tpl_subfolder (`str`): option to write template files to a subfolder within ``new_d``.
#         Default is False (write template files to ``new_d``).
#
#     chunk_len (`int`): the size of each "chunk" of files to spawn a multiprocessing.Pool member to process.
#         On windows, beware setting this much smaller than 50 because of the overhead associated with
#         spawning the pool.  This value is added to the call to `apply_list_and_array_pars`. Default is 50
#     echo (`bool`): flag to echo logger messages to the screen.  Default is True
#
# Note:
#     This is the way...
#
# Example::
#
#     pf = PstFrom("path_to_model_files","new_dir_with_pest_stuff",start_datetime="1-1-2020")
#     pf.add_parameters("hk.dat")
#     pf.add_observations("heads.csv")
#     pf.build_pst("pest.pst")
#     pe = pf.draw(100)
#     pe.to_csv("prior.csv")
# File:           c:\pest\a\a1\gmdsi_notebooks\dependencies\pyemu\pyemu\utils\pst_from.py
# Type:           type
# Subclasses:

# %%
pyemu.utils.PstFrom(model_ws,'template')
# Out:
# 2024-11-08 11:16:48.507126 starting: opening PstFrom.log for logging
# 2024-11-08 11:16:48.507126 starting PstFrom process
# 2024-11-08 11:16:48.507126 starting: setting up dirs
# 2024-11-08 11:16:48.507126 starting: copying original_d 'monthly_model_files_1lyr_newstress' to new_d 'template'
# 2024-11-08 11:16:48.703177 finished: copying original_d 'monthly_model_files_1lyr_newstress' to new_d 'template' took: 0:00:00.196051
# 2024-11-08 11:16:48.703177 finished: setting up dirs took: 0:00:00.196051

# %%
pf = pyemu.utils.PstFrom(model_ws,'template',remove_existing=True)
# Out:
# 2024-11-08 11:19:10.458399 starting: opening PstFrom.log for logging
# 2024-11-08 11:19:10.458399 starting PstFrom process
# 2024-11-08 11:19:10.458399 starting: setting up dirs
# 2024-11-08 11:19:10.458399 starting: removing existing new_d 'template'
# 2024-11-08 11:19:10.490406 finished: removing existing new_d 'template' took: 0:00:00.032007
# 2024-11-08 11:19:10.494407 starting: copying original_d 'monthly_model_files_1lyr_newstress' to new_d 'template'
# 2024-11-08 11:19:10.618440 finished: copying original_d 'monthly_model_files_1lyr_newstress' to new_d 'template' took: 0:00:00.124033
# 2024-11-08 11:19:10.622441 finished: setting up dirs took: 0:00:00.164042

# %%
pf.add_parameters?
# Out:
# Signature:
# pf.add_parameters(
#     filenames,
#     par_type,
#     zone_array=None,
#     dist_type='gaussian',
#     sigma_range=4.0,
#     upper_bound=None,
#     lower_bound=None,
#     transform=None,
#     par_name_base='p',
#     index_cols=None,
#     use_cols=None,
#     use_rows=None,
#     pargp=None,
#     pp_space=10,
#     use_pp_zones=False,
#     num_eig_kl=100,
#     spatial_reference=None,
#     geostruct=None,
#     datetime=None,
#     mfile_fmt='free',
#     mfile_skip=None,
#     mfile_sep=None,
#     ult_ubound=None,
#     ult_lbound=None,
#     rebuild_pst=False,
#     alt_inst_str='inst',
#     comment_char=None,
#     par_style='multiplier',
#     initial_value=None,
# )
# Docstring:
# Add list or array style model input files to PstFrom object.
# This method is the main entry point for adding parameters to the
# pest interface
#
# Args:
#     filenames (`str`): Model input filenames to parameterize. By default filename should give relative
#         loction from top level of pest template directory
#         (`new_d` as passed to `PstFrom()`).
#     par_type (`str`): One of `grid` - for every element, `constant` - for single
#         parameter applied to every element, `zone` - for zone-based
#         parameterization or `pilotpoint` - for
#         pilot-point base parameterization of array style input files.
#         Note `kl` not yet implemented # TODO
#     zone_array (`np.ndarray`): array defining spatial limits or zones
#         for parameterization.
#     dist_type: not yet implemented # TODO
#     sigma_range: not yet implemented # TODO
#     upper_bound (`float`): PEST parameter upper bound.  If `None`, then 1.0e+10 is used.  Default is `None` #
#     lower_bound (`float`): PEST parameter lower bound.  If `None` and `transform` is "log", then 1.0e-10 is used.
#         Otherwise, if `None`, -1.0e+10 is used.  Default is `None`
#     transform (`str`): PEST parameter transformation.  Must be either "log","none" or "fixed.  The "tied" transform
#         must be used after calling `PstFrom.build_pst()`.
#     par_name_base (`str` or `list`-like): basename for parameters that
#         are set up. If parameter file is tabular list-style file
#         (`index_cols` is not None) then :
#         len(par_name_base) must equal len(use_cols)
#     index_cols (`list`-like): if not None, will attempt to parameterize
#         expecting a tabular-style model input file. `index_cols`
#         defines the unique columns used to set up pars. If passed as a
#         list of `str`, stings are expected to denote the columns
#         headers in tabular-style parameter files; if `i` and `j` in
#         list, these columns will be used to define spatial position for
#         spatial correlations (if required). WARNING: If passed as list
#         of `int`, `i` and `j` will be assumed to be in last two entries
#         in the list. Can be passed as a dictionary using the keys
#         `i` and `j` to explicitly speficy the columns that relate to
#         model rows and columns to be identified and processed to x,y.
#     use_cols (`list`-like or `int`): for tabular-style model input file,
#         defines the columns to be parameterised
#     use_rows (`list` or `tuple`): Setup parameters for
#         only specific rows in list-style model input file.
#         Action is dependent on the the dimensions of use_rows.
#         If ndim(use_rows) < 2: use_rows is assumed to represent the row number, index slicer (equiv df.iloc),
#         for all passed files (after headers stripped). So use_rows=[0,3,5], will parameterise the
#         1st, 4th and 6th rows of each passed list-like file.
#         If ndim(use_rows) = 2: use_rows represent the index value to paramterise according to index_cols.
#         e.g. [(3,5,6)] or [[3,5,6]] would attempt to set parameters where the model file
#         values for 3 `index_cols` are 3,5,6. N.B. values in tuple are the actual
#         model file entry values.
#         If no rows in the model input file match `use_rows`, parameters
#         will be set up for all rows. Only valid/effective if index_cols is not None.
#         Default is None -- setup parameters for all rows.
#     pargp (`str`): Parameter group to assign pars to. This is PESTs
#         pargp but is also used to gather correlated parameters set up
#         using multiple `add_parameters()` calls (e.g. temporal pars)
#         with common geostructs.
#     pp_space (`float`, `int`,`str` or `pd.DataFrame`): Spatial pilot point information.
#         If `float` or `int`, AND `spatial_reference` is of type VertexGrid, it is the spacing in model length untis between pilot points.
#         If `int` it is the spacing in rows and cols of where to place pilot points.
#         If `pd.DataFrame`, then this arg is treated as a prefined set of pilot points
#         and in this case, the dataframe must have "name", "x", "y", and optionally "zone" columns.
#         If `str`, then an attempt is made to load a dataframe from a csv file (if `pp_space` ends with ".csv"),
#         shapefile (if `pp_space` ends with ".shp") or from a pilot points file.  If `pp_space` is None,
#         an integer spacing of 10 is used.  Default is None
#     use_pp_zones (`bool`): a flag to use the greater-than-zero values
#         in the zone_array as pilot point zones.
#         If False, zone_array values greater than zero are treated as a
#         single zone.  This argument is only used if `pp_space` is None
#         or `int`. Default is False.
#     num_eig_kl: TODO - impliment with KL pars
#     spatial_reference (`pyemu.helpers.SpatialReference`): If different
#         spatial reference required for pilotpoint setup.
#         If None spatial reference passed to `PstFrom()` will be used
#         for pilot-points
#     geostruct (`pyemu.geostats.GeoStruct()`): For specifying correlation
#         geostruct for pilot-points and par covariance.
#     datetime (`str`): optional %Y%m%d string or datetime object for
#         setting up temporally correlated pars. Where datetime is passed
#         correlation axis for pars will be set to timedelta.
#     mfile_fmt (`str`): format of model input file - this will be preserved
#     mfile_skip (`int` or `str`): header in model input file to skip
#         when reading and reapply when writing. Can optionally be `str` in which case `mf_skip` will be treated
#         as a `comment_char`.
#     mfile_sep (`str`): separator/delimiter in model input file.
#         If None, separator will be interpretted from file name extension.
#         `.csv` is assumed to be comma separator. Default is None
#     ult_ubound (`float`): Ultimate upper bound for model input
#         parameter once all mults are applied - ensure physical model par vals. If not passed,
#         it is set to 1.0e+30
#     ult_lbound (`float`): Ultimate lower bound for model input
#         parameter once all mults are applied.  If not passed, it is set to
#         1.0e-30 for log transform and -1.0e+30 for non-log transform
#     rebuild_pst (`bool`): (Re)Construct PstFrom.pst object after adding
#         new parameters
#     alt_inst_str (`str`): Alternative to default `inst` string in
#         parameter names. Specify ``None`` or ``""`` to exclude the instance
#         information from parameter names. For example, if parameters
#         that apply to more than one input/template file are desired.
#     comment_char (`str`): option to skip comment lines in model file.
#         This is not additive with `mfile_skip` option.
#         Warning: currently comment lines within list-style tabular data
#         will be lost.
#     par_style (`str`): either "m"/"mult"/"multiplier", "a"/"add"/"addend", or "d"/"direct" where the former sets up
#         up a multiplier and addend parameters process against the existing model input
#         array and the former sets up a template file to write the model
#         input file directly.  Default is "multiplier".
#
#     initial_value (`float`): the value to set for the `parval1` value in the control file
#         Default is 1.0
# Returns:
#     `pandas.DataFrame`: dataframe with info for new parameters
#
# Example::
#
#     # setup grid-scale direct parameters for an array of numbers
#     df = pf.add_parameters("hk.dat",par_type="grid",par_style="direct")
#     # setup pilot point multiplier parameters for an array of numbers
#     # with a pilot point being set in every 5th active model cell
#     df = pf.add_parameters("recharge.dat",par_type="pilotpoint",pp_space=5,
#                            zone_array="ibound.dat")
#     # setup a single multiplier parameter for the 4th column
#     # of a column format (list/tabular type) file
#     df = pf.add_parameters("wel_list_1.dat",par_type="constant",
#                            index_cols=[0,1,2],use_cols=[3])
# File:      c:\pest\a\a1\gmdsi_notebooks\dependencies\pyemu\pyemu\utils\pst_from.py
# Type:      method

# %%
pf.add_parameters('freyberg6.npf_k_layer1.txt',par_type='grid')
# Out:
# 2024-11-08 11:25:40.190639 transform was not passed, setting default tranform to 'log'
# 2024-11-08 11:25:40.190639 starting: adding grid type m style parameters for file(s) ['freyberg6.npf_k_layer1.txt']
# 2024-11-08 11:25:40.190639 starting: loading array template\freyberg6.npf_k_layer1.txt
# 2024-11-08 11:25:40.203641 finished: loading array template\freyberg6.npf_k_layer1.txt took: 0:00:00.013002
# 2024-11-08 11:25:40.203641 loaded array 'monthly_model_files_1lyr_newstress\freyberg6.npf_k_layer1.txt' of shape (40, 20)
# 2024-11-08 11:25:40.203641 starting: writing array-style template file 'template\p_inst0_grid.csv.tpl'
# 2024-11-08 11:25:40.203641 starting: writing template file template\p_inst0_grid.csv.tpl for ['p_inst:0']
# 2024-11-08 11:25:40.216642 finished: writing template file template\p_inst0_grid.csv.tpl for ['p_inst:0'] took: 0:00:00.013001
# 2024-11-08 11:25:40.216642 starting: writing array-based template file 'template\p_inst0_grid.csv.tpl'
# 2024-11-08 11:25:40.225650 finished: adding grid type m style parameters for file(s) ['freyberg6.npf_k_layer1.txt'] took: 0:00:00.035011
#                                                                                                                 parnme  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00          pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00          pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00          pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00          pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00          pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00
# ...                                                                                                                ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00
#
#                                                             parval1   i   j  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00          1.0   0   0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00          1.0   0   1
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00          1.0   0   2
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00          1.0   0   3
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00          1.0   0   4
# ...                                                             ...  ..  ..
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00      1.0  39  15
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00      1.0  39  16
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00      1.0  39  17
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00      1.0  39  18
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00      1.0  39  19
#
#                                                              x   y     pargp  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00       0   0  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00       0   1  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00       0   2  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00       0   3  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00       0   4  p_inst:0
# ...                                                         ..  ..       ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  39  15  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  39  16  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  39  17  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  39  18  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  39  19  p_inst:0
#
#                                                                              tpl_filename  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00      template\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00      template\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00      template\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00      template\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00      template\p_inst0_grid.csv.tpl
# ...                                                                                   ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  template\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  template\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  template\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  template\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  template\p_inst0_grid.csv.tpl
#
#                                                                             input_filename  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00      template\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00      template\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00      template\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00      template\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00      template\mult\p_inst0_grid.csv
# ...                                                                                    ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  template\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  template\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  template\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  template\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  template\mult\p_inst0_grid.csv
#
#                                                            partype partrans  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00        grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00        grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00        grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00        grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00        grid      log
# ...                                                            ...      ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00    grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00    grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00    grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00    grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00    grid      log
#
#                                                                  parubnd  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00      1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00      1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00      1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00      1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00      1.000000e+10
# ...                                                                  ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  1.000000e+10
#
#                                                                  parlbnd  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00      1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00      1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00      1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00      1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00      1.000000e-10
# ...                                                                  ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  1.000000e-10
#
#                                                            parchglim  offset  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00        factor     0.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00        factor     0.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00        factor     0.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00        factor     0.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00        factor     0.0
# ...                                                              ...     ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00    factor     0.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00    factor     0.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00    factor     0.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00    factor     0.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00    factor     0.0
#
#                                                             scale  dercom
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00        1.0       1
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00        1.0       1
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00        1.0       1
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00        1.0       1
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00        1.0       1
# ...                                                           ...     ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00    1.0       1
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00    1.0       1
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00    1.0       1
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00    1.0       1
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00    1.0       1
#
# [800 rows x 17 columns]

# %%
pf.add_observations('heads.csv',index_cols='time',use_cols='TRGW-0-15-16')
# Out:
# 2024-11-08 11:32:02.374725 starting: adding observations from output file heads.csv
# 2024-11-08 11:32:02.374725 starting: adding observations from tabular output file '['heads.csv']'
# 2024-11-08 11:32:02.374725 starting: reading list-style file: template\heads.csv
# 2024-11-08 11:32:02.382727 finished: reading list-style file: template\heads.csv took: 0:00:00.008002
# 2024-11-08 11:32:02.386728 starting: building insfile for tabular output file heads.csv
# 2024-11-08 11:32:02.390729 finished: building insfile for tabular output file heads.csv took: 0:00:00.004001
# 2024-11-08 11:32:02.390729 starting: adding observation from instruction file 'template\heads.csv.ins'
# 2024-11-08 11:32:02.406734 finished: adding observation from instruction file 'template\heads.csv.ins' took: 0:00:00.016005
# 2024-11-08 11:32:02.406734 finished: adding observations from tabular output file '['heads.csv']' took: 0:00:00.032009
# 2024-11-08 11:32:02.406734 finished: adding observations from output file heads.csv took: 0:00:00.032009
#                                                                                                               obsnme  \
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3652.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3652.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3683.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3683.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3712.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3712.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3743.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3743.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3773.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3773.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3804.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3804.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3834.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3834.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3865.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3865.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3896.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3896.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3926.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3926.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3957.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3957.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3987.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3987.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4018.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4018.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4049.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4049.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4077.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4077.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4108.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4108.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4138.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4138.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4169.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4169.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4199.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4199.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4230.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4230.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4261.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4261.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4291.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4291.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4322.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4322.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4352.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4352.5
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4383.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4383.5
#
#                                                               obsval  weight  \
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3652.5  34.378744     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3683.5  34.359508     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3712.5  34.399718     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3743.5  34.469788     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3773.5  34.526045     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3804.5  34.540116     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3834.5  34.496313     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3865.5  34.393826     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3896.5  34.257763     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3926.5  34.123023     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3957.5  34.015440     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3987.5  33.964397     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4018.5  33.978579     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4049.5  34.049943     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4077.5  34.150371     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4108.5  34.267380     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4138.5  34.354176     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4169.5  34.389448     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4199.5  34.359653     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4230.5  34.267777     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4261.5  34.139682     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4291.5  34.011223     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4322.5  33.909072     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4352.5  33.864828     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4383.5  33.915568     1.0
#
#                                                                                                   obgnme
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3652.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3683.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3712.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3743.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3773.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3804.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3834.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3865.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3896.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3926.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3957.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:3987.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4018.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4049.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4077.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4108.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4138.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4169.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4199.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4230.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4261.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4291.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4322.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4352.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16
# oname:heads.csv_otype:lst_usecol:trgw-0-15-16_time:4383.5  oname:heads.csv_otype:lst_usecol:trgw-0-15-16

# %%
pf.mod_sys_cmds.append('mf6')

# %%
pf.build_pst(filename=os.path.join(pf.new_d,freyberg.pst'),version=2)
# Out:
# noptmax:0, npar_adj:800, nnz_obs:25
# 2024-11-08 11:45:00.851624 forward_run line:pyemu.os_utils.run(r'mf6')

# %%
pyemu.os_utils.run('pestpp-ies.exe freyberg.pst',cwd='template')
